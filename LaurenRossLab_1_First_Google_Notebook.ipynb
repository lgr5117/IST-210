# %% [markdown]
# <a href="https://colab.research.google.com/github/lgr5117/IST-210/blob/master/LaurenRossLab_1_First_Google_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lauren Ross /
# Professor Patrick Dudas /
# IST 210 /
# 1 September 2020

# %% [markdown]
# Lab 1 - First Google Notebook

# %% [markdown]
# ###Do you like using Jupyter Notebooks?
# As a beginner to the IST realm and having beginner knowledge, I originally was very nervous about the idea of Jupyter Notebooks because it is not like anything I have done before. Although, with Jupyter Notebooks I feel that is very easy to catch on to which I like and I believe the more that I use it, the more and more I will like it.

# %% [markdown]
# ### What do you want to learn more about in Jupyter Notebooks?
# As I mentioned in my last response, I have beginner knowledge with information in this field and have a very small amount of experience with coding, so overall I would love to learn everything about Jupyter. Obviously such statement is very broad but I would love to gain as much knowledge as possible and further my understanding through the use of this. For example, I would love to learn the different functions of Jupyter Notebook, what codes produce what, what it can be used for, etc.

# %% [markdown]
# ### Picture from Github: My computer background
#
# ![flower.jpg](data:image/jpeg;base64,...)
