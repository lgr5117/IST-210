# %% [markdown]
# <a href="https://colab.research.google.com/github/lgr5117/IST-210/blob/master/GroupAssignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Group Assignment 2

# %% [markdown]
# Daniel Clark, Laurence Castillo, Lauren Ross
# / Patrick Dudas
# / IST 210
# / 27 Oct 2020

# %% [markdown]
# **Explanation:**
# My group is planning a car rental business near/within an airport. This is unique because customers can rent different types of vehicles including motorbikes, four wheelers, and RV's and customize different aspects of the vehicle they are renting. Before explaining the connectivity and cardinality, we wanted to explain our entities. The first entity we have on our ER Diagram is the entity "Customer" with the primary key "CustomerID." The attributes on the table "Customer" include: NumOfPurchases, PaymentMethod, FirstName, LastName, MiddleInitial, SSN, LicenseNumber, and RentDuration. Our next entity is the entity "Employee" with a primary key "EmployeeID." The attributes under Employee are: FirstName, LastName, MiddleInitial, SSN, HoursWorked, Salary, and NumOfVehiclesRented. Our third entity is "Vehicle Type" with a primary key "VehicleID." The attributes for this entity are: VehicleMake, VehicleModel, PlateNumber, Cost, WheelNumber, and TimesRented. Next, we have an entity "Vehicle Transactions" with a primary "VehicleTransactionsID." The attributes under Vehicle Transacations are: a foreign key "Customer," Cost, a foreign key "EmployeeID," and a foreign key "VehicleID." Our fifth entity is "Customizations" with a primary key "CustomizationID." We have three attributes to this entity labeled: Cost, NumberOfCustomizations, and foreign key "VehicleID." Lastly, we have an entity labeled "Customization Transactions" with a primary key "CustomizationTransacationID." The attributes to the entity are: foreign key "Customer," Cost, foreign key "EmployeeID" and foreign key "CustomizationID." When connecting our entities and attributes, we found several connections. First of, we found a relation between PK:CustomerID and Vehicle Transactions' FK:Customer as one and only one customer purchases zero to five vehicles in a month. Similarily, there is a relation between PK:CustomerID and Customization Transactions' FK:Customer by one and only one customer purchases zero to ten customizations in a month. Next when looking at the entity employee, we created a relation between PK:EmployeeID and Vehicle Transactions' FK:EmployeeID by stating that one and only one employee sells zero to a hundred vehicles in a month. As well, PK:EmployeeID relates to Customization Transaction's FK:EmployeeID by one and only one employee sells zero to a hundred customizations in a month. With the entity Customizations, we said its PK:CustomizationID connects to Customization Transactions' FK:CustomizationID through one to five customizations are sold per customization transactions. The entity Vehicle Type's PK:VehicleID relates to Customizations' FK:VehicleID through one vehicle receives zero to a hundred customizations in a month. Lastly, Vehicle Type's PK:VehicleID also connects to Vehicle Transactions' FK:VehicleID through one to five vehicles are sold per vehicle transacation.

# %% [markdown]
# **ER Diagram:**

# %% [markdown]
# ![Rental Bussiness.jpg](data:image/jpeg;base64,...)
